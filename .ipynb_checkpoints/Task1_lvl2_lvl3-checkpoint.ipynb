# %% [markdown]
# Descriptive Analysis

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing datasets from data folder
df = pd.read_csv("data/Dataset .csv")
df.shape
# Out:
# (9551, 21)

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df = df.dropna(subset=['Cuisines'])
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Calculate basic statistical measures (mean, median, standard deviation, etc.) for numerical columns.
statMeaseure = df.describe()
statMeaseure
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    130.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
# Calculate mean for numerical columns
mean = statMeaseure.mean()
print("Mean", mean)
# Out:
# Mean Restaurant ID           7.625347e+06
# Country Code            1.229579e+03
# Longitude               1.236989e+03
# Latitude                1.209900e+03
# Average Cost for two    1.035276e+05
# Price range             1.194339e+03
# Aggregate rating        1.195060e+03
# Votes                   2.653622e+03
# dtype: float64

# %%
# Calculate median for numerical columns
median = statMeaseure.median()
print("Median: ", median)
# Out:
# Median:  Restaurant ID           7.397346e+06
# Country Code            9.589604e+00
# Longitude               7.713680e+01
# Latitude                2.852455e+01
# Average Cost for two    9.501631e+02
# Price range             1.902484e+00
# Aggregate rating        2.932619e+00
# Votes                   1.433860e+02
# dtype: float64

# %%
# Calculate standard deviation for numerical columns
std_dev = statMeaseure.std()
print("Standard Deviation", std_dev)
# Out:
# Standard Deviation Restaurant ID           7.645062e+06
# Country Code            3.359529e+03
# Longitude               3.357036e+03
# Latitude                3.366791e+03
# Average Cost for two    2.814781e+05
# Price range             3.372965e+03
# Aggregate rating        3.372673e+03
# Votes                   4.697963e+03
# dtype: float64

# %%
# Explore the distribution of categorical variables like "Country Code", "City" and "Cuisines."
plt.figure(figsize=(8, 5))

# Create the figure object
sns.countplot(x = df['Country Code'])

# Set Labels
plt.xlabel('Country Codes')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Restaurants by Country Codes')

plt.show()

# %%
# Identify the top cities with the highest number of restaurants.
plt.figure(figsize=(8, 5))

# There are many cities names present in the data, so i select only the top 10 cities
sns.countplot(y = df['City'], order=df.City.value_counts().iloc[:10].index)

# Set Labels
plt.xlabel('Number of Restaurants')
plt.ylabel('Name of Cities')
plt.title('Top 10 Cities with Highest Number of Restaurants')

plt.show()

# %%
# Identify the top cuisines with the highest number of restaurants.
plt.figure(figsize=(8, 5))

# Create the figure object
# There are many cuisine names present in the data, so i select only the top 10 cuisines
sns.countplot(y = df['Cuisines'], order=df.Cuisines.value_counts().iloc[:10].index)

# Set Labels
plt.xlabel('Number of Restaurants')
plt.ylabel('Name of Cuisines')
plt.title('Top 10 Cuisines with Highest Number of Restaurants')

plt.show()

# %%
# Top cuisines and cities with the highest number of restaurants

# Identify the top 10 cuisines
top_cuisines = df['Cuisines'].value_counts().head(10)

# Display the results
print("Top 10 Cuisines with Highest Number of Restaurants:")
print(top_cuisines)
# Out:
# Top 10 Cuisines with Highest Number of Restaurants:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
# Identify the top 10 cities
top_cities = df['City'].value_counts().head(10)

# Display the results
print("Top 10 Cities with Highest Number of Restaurants:")
print(top_cities)
# Out:
# Top 10 Cities with Highest Number of Restaurants:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Amritsar          21
# Bhubaneshwar      21
# Lucknow           21
# Name: count, dtype: int64

# %% [raw]
# Task 3: Geospatial Analysis

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\delll\anaconda3\lib\site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\delll\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\delll\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\delll\anaconda3\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\delll\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\delll\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\delll\anaconda3\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\delll\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\delll\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\delll\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\delll\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\delll\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\delll\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in c:\users\delll\anaconda3\lib\site-packages (2.0.6)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\delll\anaconda3\lib\site-packages (from shapely) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geodatasets
# Out:
# Requirement already satisfied: geodatasets in c:\users\delll\anaconda3\lib\site-packages (2024.8.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pooch in c:\users\delll\anaconda3\lib\site-packages (from geodatasets) (1.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\delll\anaconda3\lib\site-packages (from pooch->geodatasets) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\delll\anaconda3\lib\site-packages (from pooch->geodatasets) (23.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\delll\anaconda3\lib\site-packages (from pooch->geodatasets) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\delll\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\delll\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\delll\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\delll\anaconda3\lib\site-packages (from requests>=2.19.0->pooch->geodatasets) (2024.6.2)

# %%
import geopandas as gpd
import geodatasets
from shapely.geometry import Point
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing restaurant locations with 'Latitude' and 'Longitude' columns
# Create Point geometry from latitude and longitude using Shapely
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df.Longitude, df.Latitude)
)

# Load the world map using geodatasets
world = gpd.read_file("data/ne_110m_admin_0_countries.shp")

# Plot the world map and overlay restaurant locations
ax = world.plot(column="CONTINENT", legend=True, figsize=(14, 12))
gdf.plot(ax=ax, marker='o', color='red', markersize=15)

# Display the map
plt.show()

# %%
# Distribution of restaurants across different cities or countries
# Set plot size
plt.figure(figsize=(8, 5))

# Create the figure object
# There are many cities names present in the data, so i select only the top 10 cities
sns.countplot(y = df['City'], order=df.City.value_counts().iloc[:10].index)

# Set Labels
plt.xlabel('Number of Restaurants')
plt.ylabel('Name of Cities')
plt.title('Distribution of Restaurants Across Cities')

# Display Chart
plt.show()

# %%
# Checking correlation between the restaurant's location and its rating
# Set plot size
plt.figure(figsize=(10, 6))

# Calculate the correlation between latitude, longitude, and ratings
correlation_matrix = df[['Latitude', 'Longitude', 'Aggregate rating']].corr()

# Create a heatmap to visualize the correlation
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Set Title
plt.title("Correlation Between Restaurant's location and Rating")

# Display Chart
plt.show()
